# %%
my_dict = {"a": 3, "b": 2, "c": 5}
print(my_dict)
my_dict.clear()
print("This my cleared dict", my_dict)
my_dict.
# Out:
# {'a': 3, 'b': 2, 'c': 5}
# This my cleared dict {}

# %%
print(my_dict)
# Out:
# {}

# %%
import random

some_list = []
max_length = 6

while max_length > len(some_list):
    num = random.randint(0, 9)
    if num not in some_list:
        some_list.append(num)
        some_list.append(num)
        print(len(some_list))
print(some_list)
# Out:
# 2
# 4
# 6
# [1, 1, 9, 9, 4, 4]

# %% [markdown]
# input("number: ")
# while

# %%
def countdown(num):
    if num == 3:
        print("Reached 3!")
    if num > 0:
        print(num)
        countdown(num - 1)
    else:
        print("Countdown complete!")


countdown(5)
# Out:
# 5
# 4
# Reached 3!
# 3
# 2
# 1
# Countdown complete!

# %%
top_num = 5
while top_num > 0:
    print(top_num)
    top_num -= 1
    if top_num == 3:
        print("Number 3 reached")
print("End of countdown")
# Out:
# 5
# 4
# Number 3 reached
# 3
# 2
# 1
# End of countdown

# %%
def main():
    print("Enter a sequence of non-decreasing numbers.")
    user_input = float(input("Enter num:"))
    stored_number = user_input
    i = 0
    while stored_number <= user_input:
        i += 1
        user_input = float(input("Enter num:"))
        another = user_input
        if another >= stored_number:
            stored_number = user_input

    print("Thanks for playing!")
    print("Sequence length:", i)


main()
# Out:
# Enter a sequence of non-decreasing numbers.
# Thanks for playing!
# Sequence length: 3

# %%
def keypress(canvas, direction):
    """
    Returns the arrow pressed
    """
    key = canvas.get_last_key_press()
    if key == "ArrowLeft":
        return "Left"
    elif key == "ArrowRight":
        return "Right"
    elif key == "ArrowUp":
        return "Up"
    elif key == "ArrowDown":
        return "Down"
    else:
        return direction

# %%
def create_goal(canvas):
    goal_top_x = random.randint(0, 19) * 20
    goal_top_y = random.randint(0, 19) * 20
    # printing the location of the initial pixel
    print("x:", goal_top_x)
    print("y:", goal_top_y)
    return canvas.create_rectangle(
        goal_top_x, goal_top_y, (goal_top_x + SIZE), (goal_top_y + SIZE), color="orange"
    )

# %%
 player_top_x = 0
    player_top_y = 0

    #player creation
    player = canvas.create_rectangle(player_top_x, player_top_y,
    player_top_x +SIZE, player_top_y +SIZE )

# %%
from graphics import Canvas
import time
import random

CANVAS_WIDTH = 400
CANVAS_HEIGHT = 400
SIZE = 20

# if you make this larger, the game will go slower
DELAY = 0.1


def create_goal(canvas):
    goal_top_x = random.randint(0, 19) * 20
    goal_top_y = random.randint(0, 19) * 20
    # printing the location of the initial pixel
    print("x:", goal_top_x)
    print("y:", goal_top_y)
    return canvas.create_rectangle(
        goal_top_x, goal_top_y, (goal_top_x + SIZE), (goal_top_y + SIZE), color="orange"
    )


def main():
    canvas = Canvas(CANVAS_WIDTH, CANVAS_HEIGHT)
    player_top_x = 0
    player_top_y = 0

    # player creation
    player = canvas.create_rectangle(
        player_top_x, player_top_y, player_top_x + SIZE, player_top_y + SIZE
    )
    # goal pixel creation
    goal = create_goal(canvas)

    # calling the animation in horizontal axis
    animate_player(canvas, player, player_top_x, player_top_y)


def animate_player(canvas, player, player_top_x, player_top_y):
    """moves the player in the horizontal axis
    player_top_x is initial X pixel location
    player_top_y is initial Y pixel location
    """

    direction = "Right"
    colission = colission_check(canvas, player)
    move_right_x_axis(canvas, player, player_top_x, player_top_y, direction, colission)
    direction = keypress(canvas, direction)
    print("End of game")


def check_direction(canvas, colission, player, direction):  # nothing right now

    while not colission_check(canvas, player, direction):
        if direction == "Down":
            move_down_y_axis(canvas, player, player_top_x, player_top_y)
        elif direction == "Right":
            move_right_x_axis(canvas, player, player_top_x, player_top_y)
        else:
            direction = direction


def move_right_x_axis(canvas, player, player_top_x, player_top_y, direction, colission):
    while (
        player_top_x < CANVAS_WIDTH - SIZE
        and direction == "Right"
        and colission == True
    ):  # X axis
        player_top_x += SIZE
        time.sleep(DELAY * 2)
        canvas.moveto(player, player_top_x, player_top_y)  # movement
        colission = colission_check(canvas, player)
        direction = keypress(canvas, direction)
        print(colission)
        print(direction)
        # check_direction(canvas, colission,player, direction)
        if direction == "Down":

            move_down_y_axis(canvas, player, player_top_x, player_top_y, direction)
        elif direction == "Right":
            move_right_x_axis(
                canvas, player, player_top_x, player_top_y, direction, colission
            )
        else:
            print("woot")


def move_down_y_axis(canvas, player, player_top_x, player_top_y, direction):
    while player_top_y < CANVAS_HEIGHT - SIZE:  # Y axis
        player_top_y += SIZE
        time.sleep(DELAY * 2)
        canvas.moveto(player, player_top_x, player_top_y)
        colission = colission_check(canvas, player)
        print(colission)


def colission_check(canvas, player):
    x = canvas.get_left_x(player)
    y = canvas.get_top_y(player)
    # Returns true if X or Y are out of canvas bound
    if x <= 0 or x >= CANVAS_WIDTH - SIZE:
        return True
    elif y <= 0 or y >= CANVAS_HEIGHT - SIZE:
        return True
    else:
        return False


def keypress(canvas, direction):
    """
    Returns the arrow pressed
    """
    key = canvas.get_last_key_press()
    if key == "ArrowLeft":
        return "Left"
    elif key == "ArrowRight":
        return "Right"
    elif key == "ArrowUp":
        return "Up"
    elif key == "ArrowDown":
        return "Down"
    else:
        return direction


if __name__ == "__main__":
    main()

# %%
    print("Previous key:", previous_key)
    key = previous_key
    x = canvas.get_left_x(player)
    y = canvas.get_top_y(player)
    x_limit = CANVAS_WIDTH - SIZE*2
    while key == 'ArrowRight' and x<= x_limit:
        x += SIZE
        canvas.moveto(player, x, y)
        key = canvas.get_last_key_press()
        if key == 'ArrowLeft':
            print('left arrow pressed!')
        if key == 'ArrowRight':
            print('right arrow pressed!')
        if key == 'ArrowUp':
            print('up arrow pressed!')
        if key == 'ArrowDown':
            print('down arrow pressed!')
        else:
            key = previous_key
            print(key)
        time.sleep(DELAY)

    while key == 'ArrowLeft' and x<= x_limit:
        x -= SIZE
        canvas.moveto(player, x, y)
        key = canvas.get_last_key_press()
        if key == 'ArrowLeft':
            print('left arrow pressed!')
        if key == 'ArrowRight':
            print('right arrow pressed!')
        if key == 'ArrowUp':
            print('up arrow pressed!')
        if key == 'ArrowDown':
            print('down arrow pressed!')
        else:
            key = previous_key
        time.sleep(DELAY)

# %%
from graphics import Canvas
import time
import random

CANVAS_WIDTH = 400
CANVAS_HEIGHT = 400
SIZE = 20

# if you make this larger, the game will go slower
DELAY = 0.1


def main():
    canvas = Canvas(CANVAS_WIDTH, CANVAS_HEIGHT)

    # TODO: your code here
    player = create_player(canvas)  # create player
    goal = create_goal(canvas)  # create goal
    previous_key = "ArrowRight"
    # time.sleep(DELAY)
    go_right(canvas, player, previous_key)
    # choose_direction(canvas, player, previous_key)


def choose_direction(canvas, player, previous_key):
    """
    Takes the user input(right, up, left or right)
    and animates the movement in that direction
    """
    while True:
        key = canvas.get_last_key_press()
        if key == "ArrowLeft" and previous_key != "ArrowRight":
            print("left arrow pressed!")
            go_left(canvas, player, key)
        if key == "ArrowRight" and previous_key != "ArrowLeft":
            print("right arrow pressed!")
            go_right(canvas, player, key)
        if key == "ArrowUp" and previous_key != "ArrowDown":
            print("up arrow pressed!")
            go_up(canvas, player, key)
        if key == "ArrowDown" and previous_key != "ArrowUp":
            print("down arrow pressed!")
            go_down(canvas, player, key)


def go_right(canvas, player, key):
    x = canvas.get_left_x(player)
    y = canvas.get_top_y(player)
    x_limit = CANVAS_WIDTH - SIZE * 2
    while x <= x_limit:
        x += SIZE
        canvas.moveto(player, x, y)
        time.sleep(DELAY)
        key = canvas.get_last_key_press()
        if key == "ArrowLeft":
            print("left arrow pressed!")
            go_left(canvas, player, key)
            break
        if key == "ArrowRight":
            print("right arrow pressed!")
            go_right(canvas, player, key)
        if key == "ArrowUp":
            print("up arrow pressed!")
            go_up(canvas, player, key)
        if key == "ArrowDown":
            print("down arrow pressed!")
            go_down(canvas, player, key)


def go_left(canvas, player, key):
    x = canvas.get_left_x(player)
    y = canvas.get_top_y(player)
    x_limit = 0
    while x > x_limit:
        x -= SIZE
        canvas.moveto(player, x, y)
        time.sleep(DELAY)
        key = canvas.get_last_key_press()
        if key == "ArrowLeft":
            print("left arrow pressed!")
            go_left(canvas, player, key)
        if key == "ArrowRight":
            print("right arrow pressed!")
            go_right(canvas, player, key)
            break
        if key == "ArrowUp":
            print("up arrow pressed!")
            go_up(canvas, player, key)
            break
        if key == "ArrowDown":
            print("down arrow pressed!")
            go_down(canvas, player, key)
            break


def go_down(canvas, player, key):
    x = canvas.get_left_x(player)
    y = canvas.get_top_y(player)
    y_limit = CANVAS_HEIGHT - SIZE * 2
    while y <= y_limit:
        y += SIZE
        canvas.moveto(player, x, y)
        time.sleep(DELAY)
        key = canvas.get_last_key_press()
        if key == "ArrowLeft":
            print("left arrow pressed!")
            go_left(canvas, player, key)
            break
        if key == "ArrowRight":
            print("right arrow pressed!")
            go_right(canvas, player, key)
            break
        if key == "ArrowUp":
            print("up arrow pressed!")
            go_up(canvas, player, key)
            break
        if key == "ArrowDown":
            print("down arrow pressed!")
            go_down(canvas, player, key)


def go_up(canvas, player, key):
    x = canvas.get_left_x(player)
    y = canvas.get_top_y(player)
    y_limit = 0
    while y > y_limit:
        y -= SIZE
        canvas.moveto(player, x, y)
        time.sleep(DELAY)
        key = canvas.get_last_key_press()
        if key == "ArrowLeft":
            print("left arrow pressed!")
            go_left(canvas, player, key)
            break
        if key == "ArrowRight":
            print("right arrow pressed!")
            go_right(canvas, player, key)
            break
        if key == "ArrowUp":
            print("up arrow pressed!")
            go_up(canvas, player, key)

        if key == "ArrowDown":
            print("down arrow pressed!")
            go_down(canvas, player, key)
            break


def create_player(canvas):
    # Create the black square
    top_x = 0
    top_y = 0
    bottom_x = top_x + SIZE
    bottom_y = top_y + SIZE
    return canvas.create_rectangle(top_x, top_y, bottom_x, bottom_y, color="black")


def create_goal(canvas):
    # Create the orange square
    top_x = random.randint(0, 19) * 20
    top_y = random.randint(0, 19) * 20
    bottom_x = top_x + SIZE
    bottom_y = top_y + SIZE
    return canvas.create_rectangle(top_x, top_y, bottom_x, bottom_y, color="orange")


if __name__ == "__main__":
    main()

# %%
# Codigo de las 6:50
from graphics import Canvas
import time
import random

CANVAS_WIDTH = 400
CANVAS_HEIGHT = 400
SIZE = 20

# if you make this larger, the game will go slower
DELAY = 0.1


def main():
    canvas = Canvas(CANVAS_WIDTH, CANVAS_HEIGHT)

    # TODO: your code here
    player = create_player(canvas)  # create player
    goal = create_goal(canvas)  # create goal
    previous_key = "ArrowRight"
    # time.sleep(DELAY)
    go_right(canvas, player, previous_key)
    # choose_direction(canvas, player, previous_key)


def choose_direction(canvas, player):
    """
    Takes the user input(right, up, left or right)
    and animates the movement in that direction
    """
    while True:
        key = canvas.get_last_key_press()
        if key == "ArrowLeft" and previous_key != "ArrowRight":
            print("left arrow pressed!")
            go_left(canvas, player, key)
        if key == "ArrowRight" and previous_key != "ArrowLeft":
            print("right arrow pressed!")
            go_right(canvas, player, key)
        if key == "ArrowUp" and previous_key != "ArrowDown":
            print("up arrow pressed!")
            go_up(canvas, player, key)
        if key == "ArrowDown" and previous_key != "ArrowUp":
            print("down arrow pressed!")
            go_down(canvas, player, key)


def go_right(canvas, player, key):
    x = canvas.get_left_x(player)
    y = canvas.get_top_y(player)
    x_limit = CANVAS_WIDTH - SIZE * 2
    while x <= x_limit:
        x += SIZE
        canvas.moveto(player, x, y)
        time.sleep(DELAY)
        # revisar la direccion direction
        # si la direccion es diferente de "ArrowRight", break
        # move player, en la direccion de direction
        direction = choose_direction(canvas, player)
        key = canvas.get_last_key_press()
        if key == "ArrowLeft":
            print("left arrow pressed!")
            go_left(canvas, player, key)
            break
        if key == "ArrowRight":
            print("right arrow pressed!")
            go_right(canvas, player, key)
        if key == "ArrowUp":
            print("up arrow pressed!")
            go_up(canvas, player, key)
        if key == "ArrowDown":
            print("down arrow pressed!")
            go_down(canvas, player, key)


def go_left(canvas, player, key):
    x = canvas.get_left_x(player)
    y = canvas.get_top_y(player)
    x_limit = 0
    while x > x_limit:
        x -= SIZE
        canvas.moveto(player, x, y)
        time.sleep(DELAY)
        key = canvas.get_last_key_press()
        if key == "ArrowLeft":
            print("left arrow pressed!")
            go_left(canvas, player, key)
        if key == "ArrowRight":
            print("right arrow pressed!")
            go_right(canvas, player, key)
            break
        if key == "ArrowUp":
            print("up arrow pressed!")
            go_up(canvas, player, key)
            break
        if key == "ArrowDown":
            print("down arrow pressed!")
            go_down(canvas, player, key)
            break


def go_down(canvas, player, key):
    x = canvas.get_left_x(player)
    y = canvas.get_top_y(player)
    y_limit = CANVAS_HEIGHT - SIZE * 2
    while y <= y_limit:
        y += SIZE
        canvas.moveto(player, x, y)
        time.sleep(DELAY)
        key = canvas.get_last_key_press()
        if key == "ArrowLeft":
            print("left arrow pressed!")
            go_left(canvas, player, key)
            break
        if key == "ArrowRight":
            print("right arrow pressed!")
            go_right(canvas, player, key)
            break
        if key == "ArrowUp":
            print("up arrow pressed!")
            go_up(canvas, player, key)
            break
        if key == "ArrowDown":
            print("down arrow pressed!")
            go_down(canvas, player, key)


def go_up(canvas, player, key):
    x = canvas.get_left_x(player)
    y = canvas.get_top_y(player)
    y_limit = 0
    while y > y_limit:
        y -= SIZE
        canvas.moveto(player, x, y)
        time.sleep(DELAY)
        key = canvas.get_last_key_press()
        if key == "ArrowLeft":
            print("left arrow pressed!")
            go_left(canvas, player, key)
            break
        if key == "ArrowRight":
            print("right arrow pressed!")
            go_right(canvas, player, key)
            break
        if key == "ArrowUp":
            print("up arrow pressed!")
            go_up(canvas, player, key)

        if key == "ArrowDown":
            print("down arrow pressed!")
            go_down(canvas, player, key)
            break


def create_player(canvas):
    # Create the black square
    top_x = 0
    top_y = 0
    bottom_x = top_x + SIZE
    bottom_y = top_y + SIZE
    return canvas.create_rectangle(top_x, top_y, bottom_x, bottom_y, color="black")


def create_goal(canvas):
    # Create the orange square
    top_x = random.randint(0, 19) * 20
    top_y = random.randint(0, 19) * 20
    bottom_x = top_x + SIZE
    bottom_y = top_y + SIZE
    return canvas.create_rectangle(top_x, top_y, bottom_x, bottom_y, color="orange")


if __name__ == "__main__":
    main()

# %%
# pseudo working
from graphics import Canvas
import time
import random

CANVAS_WIDTH = 400
CANVAS_HEIGHT = 400
SIZE = 20

# if you make this larger, the game will go slower
DELAY = 0.1


def main():
    canvas = Canvas(CANVAS_WIDTH, CANVAS_HEIGHT)

    # TODO: your code here
    player = create_player(canvas)  # create player
    goal = create_goal(canvas)  # create goal
    direction = "right"
    time.sleep(DELAY)
    go_right(canvas, player, direction)


def choose_direction(canvas, player, direction):
    """
    Takes the user input(right, up, left or right)
    and animates the movement in that direction
    """
    key = canvas.get_last_key_press()
    if key == "ArrowLeft":
        # print('left arrow pressed!')
        return "left"
    if key == "ArrowRight":
        # print('right arrow pressed!')
        return "right"
    if key == "ArrowUp":
        # print('up arrow pressed!')
        return "up"
    if key == "ArrowDown":
        # print('down arrow pressed!')
        return "down"
    if key == None:
        return direction


def go_right(canvas, player, direction):
    # direction is the current facing direction
    x = canvas.get_left_x(player)
    y = canvas.get_top_y(player)
    x_limit = CANVAS_WIDTH - SIZE * 2
    while x <= x_limit:
        x += SIZE
        canvas.moveto(player, x, y)  # MOVE
        colission, current_goal = colission_check(canvas, player)  # Check colission
        if colission:
            print(current_goal)
            break
        # revisar la direccion direction
        # si la direccion es diferente de "ArrowRight", break
        # move player, en la direccion de direction
        direction = choose_direction(canvas, player, direction)  # ARROW Press
        time.sleep(DELAY)
        # print("curren direction is ", direction)
        if direction == "right":
            continue
        else:
            break
    if direction == "left":
        go_left(canvas, player, direction)
    elif direction == "up":
        go_up(canvas, player, direction)
    elif direction == "down":
        go_down(canvas, player, direction)
    end_game()


def go_left(canvas, player, direction):
    x = canvas.get_left_x(player)
    y = canvas.get_top_y(player)
    x_limit = 0
    while x > x_limit:
        x -= SIZE
        canvas.moveto(player, x, y)
        time.sleep(DELAY)
        colission = colission_check(canvas, player)  # Check colission
        if colission:
            break
        # revisar la direccion direction
        # si la direccion es diferente de "ArrowRight", break
        # move player, en la direccion de direction
        direction = choose_direction(canvas, player, direction)
        if direction != "left":
            break
    if direction == "right":
        go_right(canvas, player, direction)
    elif direction == "up":
        go_up(canvas, player, direction)
    elif direction == "down":
        go_down(canvas, player, direction)


def go_down(canvas, player, direction):
    x = canvas.get_left_x(player)
    y = canvas.get_top_y(player)
    y_limit = CANVAS_HEIGHT - SIZE * 2
    while y <= y_limit:
        y += SIZE
        canvas.moveto(player, x, y)
        time.sleep(DELAY)
        colission, goal_object = colission_check(canvas, player)  # Check colission
        if colission:
            break
        # revisar la direccion direction
        # si la direccion es diferente de "ArrowRight", break
        # move player, en la direccion de direction
        direction = choose_direction(canvas, player, direction)
        if direction != "down":
            delete_goal(canvas)
            break
    if direction == "right":
        go_right(canvas, player, direction)
    elif direction == "up":
        go_up(canvas, player, direction)
    elif direction == "left":
        go_left(canvas, player, direction)


def go_up(canvas, player, direction):
    x = canvas.get_left_x(player)
    y = canvas.get_top_y(player)
    y_limit = 0
    while y > y_limit:
        y -= SIZE
        canvas.moveto(player, x, y)
        time.sleep(DELAY)
        colission = colission_check(canvas, player)  # Check colission
        if (
            colission
        ):  # for now is break, but should differentiate between goal and self
            break
        # revisar la direccion direction
        # si la direccion es diferente de "ArrowRight", break
        # move player, en la direccion de direction
        direction = choose_direction(canvas, player, direction)
        if direction != "up":
            break
    if direction == "right":
        go_right(canvas, player, direction)
    elif direction == "left":
        go_left(canvas, player, direction)
    elif direction == "down":
        go_down(canvas, player, direction)


def delete_goal(canvas):
    pass


def colission_check(canvas, player):  # check for overlapping objects
    player_left_x = canvas.get_left_x(player)  # player coordenates
    player_top_y = canvas.get_top_y(player)
    player_right_x = player_left_x + SIZE
    player_bottom_y = player_top_y + SIZE

    overlapping_objects = canvas.find_overlapping(
        player_left_x, player_top_y, player_right_x, player_bottom_y
    )
    # print("The overlapping objects are:", overlapping_objects)
    overlaping_length = len(overlapping_objects)
    if overlaping_length > 1:
        return True, overlapping_objects
    else:
        return False, overlapping_objects


def end_game():
    print("You played well")


def create_player(canvas):
    # Create the black square
    top_x = 0
    top_y = 0
    bottom_x = top_x + SIZE
    bottom_y = top_y + SIZE
    return canvas.create_rectangle(top_x, top_y, bottom_x, bottom_y, color="black")


def create_goal(canvas):
    # Create the orange square
    top_x = random.randint(0, 19) * 20
    top_y = random.randint(0, 19) * 20
    bottom_x = top_x + SIZE
    bottom_y = top_y + SIZE
    return canvas.create_rectangle(top_x, top_y, bottom_x, bottom_y, color="orange")


if __name__ == "__main__":
    main()

# %%
# working on colission
from graphics import Canvas
import time
import random

CANVAS_WIDTH = 400
CANVAS_HEIGHT = 400
SIZE = 20

# if you make this larger, the game will go slower
DELAY = 0.1


def main():
    canvas = Canvas(CANVAS_WIDTH, CANVAS_HEIGHT)

    # TODO: your code here
    player = create_player(canvas)  # create player
    goal = create_goal(canvas)  # create goal
    direction = "right"
    time.sleep(DELAY)
    go_right(canvas, player, direction)


def choose_direction(canvas, player, direction):
    """
    Takes the user input(right, up, left or right)
    and animates the movement in that direction
    """
    key = canvas.get_last_key_press()
    if key == "ArrowLeft":
        # print('left arrow pressed!')
        return "left"
    if key == "ArrowRight":
        # print('right arrow pressed!')
        return "right"
    if key == "ArrowUp":
        # print('up arrow pressed!')
        return "up"
    if key == "ArrowDown":
        # print('down arrow pressed!')
        return "down"
    if key == None:
        return direction


def go_right(canvas, player, direction):
    # direction is the current facing direction
    x = canvas.get_left_x(player)
    y = canvas.get_top_y(player)
    x_limit = CANVAS_WIDTH - SIZE * 2
    while x <= x_limit:
        x += SIZE
        canvas.moveto(player, x, y)  # MOVE
        colission, current_goal = colission_check(canvas, player)  # Check colission
        if colission:
            print(current_goal)
            break
        # revisar la direccion direction
        # si la direccion es diferente de "ArrowRight", break
        # move player, en la direccion de direction
        direction = choose_direction(canvas, player, direction)  # ARROW Press
        time.sleep(DELAY)
        # print("curren direction is ", direction)
        if direction == "right":
            continue
        else:
            break
    if direction == "left":
        go_left(canvas, player, direction)
    elif direction == "up":
        go_up(canvas, player, direction)
    elif direction == "down":
        go_down(canvas, player, direction)
    end_game()


def go_left(canvas, player, direction):
    x = canvas.get_left_x(player)
    y = canvas.get_top_y(player)
    x_limit = 0
    while x > x_limit:
        x -= SIZE
        canvas.moveto(player, x, y)
        time.sleep(DELAY)
        colission, current_goal = colission_check(canvas, player)  # Check colission
        if colission:
            print(current_goal)
            break
        # revisar la direccion direction
        # si la direccion es diferente de "ArrowRight", break
        # move player, en la direccion de direction
        direction = choose_direction(canvas, player, direction)
        if direction != "left":
            break
    if direction == "right":
        go_right(canvas, player, direction)
    elif direction == "up":
        go_up(canvas, player, direction)
    elif direction == "down":
        go_down(canvas, player, direction)


def go_down(canvas, player, direction):
    x = canvas.get_left_x(player)
    y = canvas.get_top_y(player)
    y_limit = CANVAS_HEIGHT - SIZE * 2
    while y <= y_limit:
        y += SIZE
        canvas.moveto(player, x, y)
        time.sleep(DELAY)
        colission, current_goal = colission_check(canvas, player)  # Check colission
        if colission:
            print(current_goal)
            break
        # revisar la direccion direction
        # si la direccion es diferente de "ArrowRight", break
        # move player, en la direccion de direction
        direction = choose_direction(canvas, player, direction)
        if direction != "down":
            delete_goal(canvas)
            break
    if direction == "right":
        go_right(canvas, player, direction)
    elif direction == "up":
        go_up(canvas, player, direction)
    elif direction == "left":
        go_left(canvas, player, direction)


def go_up(canvas, player, direction):
    x = canvas.get_left_x(player)
    y = canvas.get_top_y(player)
    y_limit = 0
    while y > y_limit:
        y -= SIZE
        canvas.moveto(player, x, y)
        time.sleep(DELAY)
        colission, current_goal = colission_check(canvas, player)  # Check colission
        if colission:
            print(current_goal)
            break
        # revisar la direccion direction
        # si la direccion es diferente de "ArrowRight", break
        # move player, en la direccion de direction
        direction = choose_direction(canvas, player, direction)
        if direction != "up":
            break
    if direction == "right":
        go_right(canvas, player, direction)
    elif direction == "left":
        go_left(canvas, player, direction)
    elif direction == "down":
        go_down(canvas, player, direction)


def delete_goal(canvas):
    pass


def colission_check(canvas, player):  # check for overlapping objects
    player_left_x = canvas.get_left_x(player)  # player coordenates
    player_top_y = canvas.get_top_y(player)
    player_right_x = player_left_x + SIZE
    player_bottom_y = player_top_y + SIZE

    overlapping_objects = canvas.find_overlapping(
        player_left_x, player_top_y, player_right_x, player_bottom_y
    )
    # print("The overlapping objects are:", overlapping_objects)
    overlaping_length = len(overlapping_objects)
    if overlaping_length > 1:
        return True, overlapping_objects
    else:
        return False, overlapping_objects


def end_game():
    print("You played well")


def create_player(canvas):
    # Create the black square
    top_x = 0
    top_y = 0
    bottom_x = top_x + SIZE
    bottom_y = top_y + SIZE
    return canvas.create_rectangle(top_x, top_y, bottom_x, bottom_y, color="black")


def create_goal(canvas):
    # Create the orange square
    top_x = random.randint(0, 19) * 20
    top_y = random.randint(0, 19) * 20
    bottom_x = top_x + SIZE
    bottom_y = top_y + SIZE
    return canvas.create_rectangle(top_x, top_y, bottom_x, bottom_y, color="orange")


if __name__ == "__main__":
    main()

# %%
# mini snake
from graphics import Canvas
import time
import random

CANVAS_WIDTH = 400
CANVAS_HEIGHT = 400
SIZE = 20

# if you make this larger, the game will go slower
DELAY = 0.1


def main():
    canvas = Canvas(CANVAS_WIDTH, CANVAS_HEIGHT)

    # TODO: your code here
    player = create_player(canvas)  # create player
    goal = create_goal(canvas)  # create goal
    direction = "right"
    time.sleep(DELAY)
    go_right(canvas, player, direction, goal)


def choose_direction(canvas, player, direction):
    """
    Takes the user input(right, up, left or right)
    and animates the movement in that direction
    """
    key = canvas.get_last_key_press()
    if key == "ArrowLeft":
        # print('left arrow pressed!')
        return "left"
    if key == "ArrowRight":
        # print('right arrow pressed!')
        return "right"
    if key == "ArrowUp":
        # print('up arrow pressed!')
        return "up"
    if key == "ArrowDown":
        # print('down arrow pressed!')
        return "down"
    if key == None:
        return direction


def go_right(canvas, player, direction, goal):
    # direction is the current facing direction
    x = canvas.get_left_x(player)
    y = canvas.get_top_y(player)
    x_limit = CANVAS_WIDTH - SIZE * 2
    while x <= x_limit:
        x += SIZE
        canvas.moveto(player, x, y)  # MOVE
        colission, current_goal = colission_check(canvas, player)  # Check colission
        if colission:
            print(current_goal)
            canvas.delete(goal)
            goal = create_goal(canvas)

        # revisar la direccion direction
        # si la direccion es diferente de "ArrowRight", break
        # move player, en la direccion de direction
        direction = choose_direction(canvas, player, direction)  # ARROW Press
        time.sleep(DELAY)
        # print("curren direction is ", direction)
        if direction == "right":
            continue
        else:
            break
    if direction == "left":
        go_left(canvas, player, direction, goal)
    elif direction == "up":
        go_up(canvas, player, direction, goal)
    elif direction == "down":
        go_down(canvas, player, direction, goal)
    end_game()


def go_left(canvas, player, direction, goal):
    x = canvas.get_left_x(player)
    y = canvas.get_top_y(player)
    x_limit = 0
    while x > x_limit:
        x -= SIZE
        canvas.moveto(player, x, y)
        time.sleep(DELAY)
        colission, current_goal = colission_check(canvas, player)  # Check colission
        if colission:
            print(current_goal)
            canvas.delete(goal)
            goal = create_goal(canvas)

        # revisar la direccion direction
        # si la direccion es diferente de "ArrowRight", break
        # move player, en la direccion de direction
        direction = choose_direction(canvas, player, direction)
        if direction != "left":
            break
    if direction == "right":
        go_right(canvas, player, direction, goal)
    elif direction == "up":
        go_up(canvas, player, direction, goal)
    elif direction == "down":
        go_down(canvas, player, direction, goal)


def go_down(canvas, player, direction, goal):
    x = canvas.get_left_x(player)
    y = canvas.get_top_y(player)
    y_limit = CANVAS_HEIGHT - SIZE * 2
    while y <= y_limit:
        y += SIZE
        canvas.moveto(player, x, y)
        time.sleep(DELAY)
        colission, current_goal = colission_check(canvas, player)  # Check colission
        if colission:
            print(current_goal)
            canvas.delete(goal)
            goal = create_goal(canvas)
        # revisar la direccion direction
        # si la direccion es diferente de "ArrowRight", break
        # move player, en la direccion de direction
        direction = choose_direction(canvas, player, direction)
        if direction != "down":
            delete_goal(canvas)
            break
    if direction == "right":
        go_right(canvas, player, direction, goal)
    elif direction == "up":
        go_up(canvas, player, direction, goal)
    elif direction == "left":
        go_left(canvas, player, direction, goal)


def go_up(canvas, player, direction, goal):
    x = canvas.get_left_x(player)
    y = canvas.get_top_y(player)
    y_limit = 0
    while y > y_limit:
        y -= SIZE
        canvas.moveto(player, x, y)
        time.sleep(DELAY)
        colission, current_goal = colission_check(canvas, player)  # Check colission
        if colission:
            print(current_goal)
            canvas.delete(goal)
            goal = create_goal(canvas)
        # revisar la direccion direction
        # si la direccion es diferente de "ArrowRight", break
        # move player, en la direccion de direction
        direction = choose_direction(canvas, player, direction)
        if direction != "up":
            break
    if direction == "right":
        go_right(canvas, player, direction, goal)
    elif direction == "left":
        go_left(canvas, player, direction, goal)
    elif direction == "down":
        go_down(canvas, player, direction, goal)


def delete_goal(canvas):
    pass


def colission_check(canvas, player):  # check for overlapping objects
    player_left_x = canvas.get_left_x(player)  # player coordenates
    player_top_y = canvas.get_top_y(player)
    player_right_x = player_left_x + SIZE
    player_bottom_y = player_top_y + SIZE

    overlapping_objects = canvas.find_overlapping(
        player_left_x, player_top_y, player_right_x, player_bottom_y
    )
    # print("The overlapping objects are:", overlapping_objects)
    overlaping_length = len(overlapping_objects)
    if overlaping_length > 1:
        return True, overlapping_objects
    else:
        return False, overlapping_objects


def end_game():
    print("You played well")


def create_player(canvas):
    # Create the black square
    top_x = 0
    top_y = 0
    bottom_x = top_x + SIZE
    bottom_y = top_y + SIZE
    return canvas.create_rectangle(top_x, top_y, bottom_x, bottom_y, color="black")


def create_goal(canvas):
    # Create the orange square
    top_x = random.randint(0, 19) * 20
    top_y = random.randint(0, 19) * 20
    bottom_x = top_x + SIZE
    bottom_y = top_y + SIZE
    return canvas.create_rectangle(top_x, top_y, bottom_x, bottom_y, color="orange")


if __name__ == "__main__":
    main()

    """
    Extensions

You did it! Congratulations, that was a huge program. If you want to keep going, awesome. Add any extension you like. Here are a few that we think are fun:

Get faster each time the player touches the goal.

Keep track of points

Add obstacles

Full Snake?

If you are feeling very adventurous you could try and implement the full game of snake. Here is a link to an online version: https://playsnake.org/. The full game of snake is a hard challenge even for a well seasoned programmer. If you do go down this path, here are a few pro tips:

Program your snake in a new project (leave this one as baby snake)

Represent your snake using a list of rectangles (where the rectangles are the shapes returned by create_rect). This will make it much easier to move your snake. You will only need to change the head and the tail.

Us the find_overlapping function to tell if you have hit yourself.


    """

# %%
some_list = [200, 0, 220, 20]
another_list
for i in range(len(some_list)):

# %%
# snake with start and end_screen
from graphics import Canvas
import time
import random

CANVAS_WIDTH = 400
CANVAS_HEIGHT = 400
SIZE = 20

# if you make this larger, the game will go slower
DELAY = 0.1


def set_background(canvas):
    canvas.create_rectangle(0, 0, CANVAS_WIDTH, CANVAS_HEIGHT, color="green")


def clear_canvas(canvas):
    canvas.clear()


def start_game(canvas):
    # When Enter is pressed start game
    while True:
        key = canvas.get_last_key_press()
        print(key)
        time.sleep(0.4)
        if key == "Enter":
            break


def start_screen(canvas):
    """
    Create a starting screen with title and instruction to start
    """
    backbround = canvas.create_rectangle(
        0, 0, CANVAS_HEIGHT, CANVAS_WIDTH, color="brown"
    )

    backbround = canvas.create_rectangle(
        0, 0, CANVAS_HEIGHT, CANVAS_WIDTH, color="cyan"
    )

    x_point_three = CANVAS_WIDTH * 0.3
    x_point_four = CANVAS_WIDTH * 0.4
    y_center = CANVAS_HEIGHT / 2
    y_third = CANVAS_HEIGHT / 3
    title = canvas.create_text(
        x_point_three, y_third, text="CODE IN PLACE, SNAKE GAME", color="orange"
    )
    enter_to_play = canvas.create_text(
        x_point_four, y_center, text="Press Enter to play!", color="green"
    )


def main():
    canvas = Canvas(CANVAS_WIDTH, CANVAS_HEIGHT)
    # Starting the game
    start_screen(canvas)
    start_game(canvas)
    clear_canvas(canvas)

    # actual game
    player = create_player(canvas)  # create player
    goal = create_goal(canvas)  # create goal
    direction = "right"
    time.sleep(DELAY)
    go_right(canvas, player, direction, goal)


def choose_direction(canvas, player, direction):
    """
    Takes the user input(right, up, left or right)
    and animates the movement in that direction
    """
    key = canvas.get_last_key_press()
    if key == "ArrowLeft":
        # print('left arrow pressed!')
        return "left"
    if key == "ArrowRight":
        # print('right arrow pressed!')
        return "right"
    if key == "ArrowUp":
        # print('up arrow pressed!')
        return "up"
    if key == "ArrowDown":
        # print('down arrow pressed!')
        return "down"
    if key == None:
        return direction


def go_right(canvas, player, direction, goal):
    # direction is the current facing direction
    x = canvas.get_left_x(player)
    y = canvas.get_top_y(player)
    x_limit = CANVAS_WIDTH - SIZE
    while x < x_limit:
        x += SIZE
        canvas.moveto(player, x, y)  # MOVE
        time.sleep(DELAY)
        colission, current_goal = colission_check(canvas, player)  # Check colission
        if colission:
            print(current_goal)
            canvas.delete(goal)
            goal = create_goal(canvas)

        # revisar la direccion direction
        # si la direccion es diferente de "ArrowRight", break
        # move player, en la direccion de direction
        direction = choose_direction(canvas, player, direction)  # ARROW Press
        # print("curren direction is ", direction)
        if direction == "right":
            continue
        else:
            break
    if direction == "left":
        go_left(canvas, player, direction, goal)
    elif direction == "up":
        go_up(canvas, player, direction, goal)
    elif direction == "down":
        go_down(canvas, player, direction, goal)
    end_game(canvas)


def go_left(canvas, player, direction, goal):
    x = canvas.get_left_x(player)
    y = canvas.get_top_y(player)
    x_limit = 0
    while x > x_limit:
        x -= SIZE
        canvas.moveto(player, x, y)
        time.sleep(DELAY)
        colission, current_goal = colission_check(canvas, player)  # Check colission
        if colission:
            print(current_goal)
            canvas.delete(goal)
            goal = create_goal(canvas)

        # revisar la direccion direction
        # si la direccion es diferente de "ArrowRight", break
        # move player, en la direccion de direction
        direction = choose_direction(canvas, player, direction)
        if direction != "left":
            break
    if direction == "right":
        go_right(canvas, player, direction, goal)
    elif direction == "up":
        go_up(canvas, player, direction, goal)
    elif direction == "down":
        go_down(canvas, player, direction, goal)


def go_down(canvas, player, direction, goal):
    x = canvas.get_left_x(player)
    y = canvas.get_top_y(player)
    y_limit = CANVAS_HEIGHT - SIZE
    while y < y_limit:
        y += SIZE
        canvas.moveto(player, x, y)
        time.sleep(DELAY)
        colission, current_goal = colission_check(canvas, player)  # Check colission
        if colission:
            print(current_goal)
            canvas.delete(goal)
            goal = create_goal(canvas)
        # revisar la direccion direction
        # si la direccion es diferente de "ArrowRight", break
        # move player, en la direccion de direction
        direction = choose_direction(canvas, player, direction)
        if direction != "down":
            delete_goal(canvas)
            break
    if direction == "right":
        go_right(canvas, player, direction, goal)
    elif direction == "up":
        go_up(canvas, player, direction, goal)
    elif direction == "left":
        go_left(canvas, player, direction, goal)


def go_up(canvas, player, direction, goal):
    x = canvas.get_left_x(player)
    y = canvas.get_top_y(player)
    y_limit = 0
    while y > y_limit:
        y -= SIZE
        canvas.moveto(player, x, y)
        time.sleep(DELAY)
        colission, current_goal = colission_check(canvas, player)  # Check colission
        if colission:
            print(current_goal)
            canvas.delete(goal)
            goal = create_goal(canvas)
        # revisar la direccion direction
        # si la direccion es diferente de "ArrowRight", break
        # move player, en la direccion de direction
        direction = choose_direction(canvas, player, direction)
        if direction != "up":
            break
    if direction == "right":
        go_right(canvas, player, direction, goal)
    elif direction == "left":
        go_left(canvas, player, direction, goal)
    elif direction == "down":
        go_down(canvas, player, direction, goal)


def delete_goal(canvas):
    pass


def colission_check(canvas, player):  # check for overlapping objects
    player_left_x = canvas.get_left_x(player)  # player coordenates
    player_top_y = canvas.get_top_y(player)
    player_right_x = player_left_x + SIZE
    player_bottom_y = player_top_y + SIZE

    overlapping_objects = canvas.find_overlapping(
        player_left_x, player_top_y, player_right_x, player_bottom_y
    )
    # print("The overlapping objects are:", overlapping_objects)
    overlaping_length = len(overlapping_objects)
    if overlaping_length > 1:
        return True, overlapping_objects
    else:
        return False, overlapping_objects


def end_game(canvas):
    end_screen(canvas)
    print("You played well")


def end_screen(canvas):
    """
    Create screen hopefully with the result
    """
    clear_canvas(canvas)
    backbround = canvas.create_rectangle(
        0, 0, CANVAS_HEIGHT, CANVAS_WIDTH, color="brown"
    )
    time.sleep(0.1)
    backbround = canvas.create_rectangle(
        0, 0, CANVAS_HEIGHT, CANVAS_WIDTH, color="cyan"
    )

    x_point_three = CANVAS_WIDTH * 0.3
    x_point_four = CANVAS_WIDTH * 0.4
    y_center = CANVAS_HEIGHT / 2
    y_third = CANVAS_HEIGHT / 3
    cheering = canvas.create_text(
        x_point_three, y_third, text="You played well", color="orange"
    )
    score_display = canvas.create_text(
        x_point_three, y_center, text="Your score is:(some score)", color="green"
    )
    enter_to_play = canvas.create_text(
        x_point_three, y_center + SIZE, text="Press Enter to continue", color="green"
    )
    start_game(canvas)
    main()


def create_player(canvas):
    # Create the black square
    top_x = 0
    top_y = 0
    bottom_x = top_x + SIZE
    bottom_y = top_y + SIZE
    return canvas.create_rectangle(top_x, top_y, bottom_x, bottom_y, color="black")


def create_goal(canvas):
    # Create the orange square
    top_x = random.randint(0, 19) * 20
    top_y = random.randint(0, 19) * 20
    bottom_x = top_x + SIZE
    bottom_y = top_y + SIZE
    return canvas.create_rectangle(top_x, top_y, bottom_x, bottom_y, color="orange")


if __name__ == "__main__":
    main()
